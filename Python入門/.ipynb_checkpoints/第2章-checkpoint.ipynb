# %%
name=input("what is your name?")
print('Hello'+ name)

# %%
name=input("what is your name?")
print("Hello"+name)

# %%
print("Hello")
print()
print("Taro")

# %%
print("Hello",end=",")
print("Taro")

# %%
print("Hello","Taro")
print("Hello","Taro",sep=",")

# %%
print("Hello,Taro")

# %%
number=100
Number

# %%
number=100
number
