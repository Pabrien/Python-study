# %%
print(250 * 3)

# %%
print(apple * n)

# %%
apple = 250
n = 3
print(apple * n)

# %%
apple , n = 250, 3
print(apple * n)

# %%
apple = 300
apple = apple * 1.1
print(apple)

# %%
type(250)

# %%
type(10.5)

# %%
a = 250
print(type(a))
a = 10.5
print(type(a))
a = "Hello"
print(type(a))

# %%
5+3

# %%
answer = 5+3
print(answer)

# %%
answer = 5.0 + 3
print(answer)

# %%
answer = 100 + 5*2
print(answer)

# %%
answer = 1 + 2 - 3
print(answer)

# %%
answer = (100 + 5)* 2
print(answer)

# %%
answer = 5 * ((5+1) / 2)
print(answer)

# %%
cnt = 10
cnt = cnt + 1
print(cnt)

# %%
answer = 0.1 + 0.1 + 0.1
print(answer)

# %%
PI = 3.141592653589793237
round(PI , 2)

# %%
round(PI, 3)

# %%
round(PI)

# %%
round(1.5)

# %%
round(2.5)

# %%
msg = "Hello"
msg

# %%
name = 'こんにちは'
name

# %%
zip_code = "131-8634"
zip_code

# %%
zip_code = 131-8634
zip_code

# %%
price = 1980
price

# %%
pin_code = "1980"
pin_code

# %%
pin_code = "1980"
print(pin_code)

# %%
msg = "こんにちは\n太郎くん"
print(msg)

# %%
msg = "こんにちは\t太郎くん"
print(msg)

# %%
msg = "私の名前は\"太郎\"です"
print(msg)

# %%
msg = '私の名前は"太郎"です'
print(msg)

# %%
msg = "こんにちは\n太郎くん"
msg

# %%
name = input("What's your name?")
print(f"Hello {name}!")
# Out:
# Hello hanako!

# %%
name = input("What's your name? ")
print(f"Hello {name}!")
# Out:
# Hello hanako!

# %%
price = 1980
label = price + "円"
label
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 price = 1980
# ----> 2 label = price + "円"
#       3 label
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
cm = input("長さをセンチで入力")
m = cm / 100
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 cm = input("長さをセンチで入力")
# ----> 2 m = cm / 100
#       3 print(m)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
m = input("長さをメートルで入力　")
cm = m * 100
print(cm)
# Out:
# 1.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.51.5

# %%
str_cm = input("長さをセンチで入力　")
cm = int(str_cm)
m = cm / 100
print(m)
# Out:
# 14713.84

# %%
m = float(input("長さをメートルで入力　"))
cm = m * 100
print(cm)
# Out:
# 150.0

# %%
price = 1980
label = price + "円"
print(label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 price = 1980
# ----> 2 label = price + "円"
#       3 print(label)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
price = 1980
label = str(price)+"円"
print(label)
# Out:
# 1980円

# %%
float(10)
# Out:
# 10.0

# %%
int(100.5)
# Out:
# 100

# %%
orange = 500
n = 8
price = print(orange * n)
print(price)
# Out:
# 4000
# None

# %%
name = "jyct"
message = "gufyuk"
print(name + "くん、" + message)
# Out:
# jyctくん、gufyuk

# %%
print(int([3 + 4]* 4 / 2 + cm))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(int([3 + 4]* 4 / 2 + cm))
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'
