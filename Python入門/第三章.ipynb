# %%
print(250 * 3)
# Out:
# 750

# %%
print(apple * n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(apple * n)
#
# NameError: name 'apple' is not defined

# %%
apple = 250
n = 3
print(apple * n)
# Out:
# 750

# %%
apple , n = 250, 3
print(apple * n)
# Out:
# 750

# %%
apple = 300
apple = apple * 1.1
print(apple)
# Out:
# 330.0

# %%
type(250)
# Out:
# int

# %%
type(10.5)
# Out:
# float

# %%
a = 250
print(type(a))
a = 10.5
print(type(a))
a = "Hello"
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
