# %%
name=input("what is your name?")
print('Hello'+ name)

# %%
name=input("what is your name?")
print("Hello"+name)

# %%
print("Hello")
print()
print("Taro")

# %%
print("Hello",end=",")
print("Taro")

# %%
print("Hello","Taro")
print("Hello","Taro",sep=",")

# %%
print("Hello,Taro")

# %%
number=100
Number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 number=100
# ----> 2 Number
#
# NameError: name 'Number' is not defined

# %%
number=100
number
# Out:
# 100

# %%
name=input("what is your name?");print(name)
# Out:
# what is your name? Taro
# Taro

# %%
score=int(input("点数を入力"))
if score>=40:
    print("合格")
else:print("追試")
# Out:
# 点数を入力 96
# 合格

# %%
#name=input("what is your name?")
name="Taro"
print('Hello'+name)
# Out:
# HelloTaro

# %%
score=int(input("点数を入力"))
if score>=80:
    print("A")
    """
    elif score=40:
    print("C")
    """
else:
    print("追試")
# Out:
# 点数を入力 75
# 追試

# %%
data=[[1,2,3],
      [4,5,6]
      [7,8,9]]
print(data)
# Out:
# <>:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\R20260207\AppData\Local\Temp\ipykernel_8136\3855736775.py:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   [4,5,6]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 data=[[1,2,3],
# ----> 2       [4,5,6]
#       3       [7,8,9]]
#       4 print(data)
#
# TypeError: list indices must be integers or slices, not tuple
