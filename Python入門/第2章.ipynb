# %%
name=input("what is your name?")
print('Hello'+ name)

# %%
name=input("what is your name?")
print("Hello"+name)

# %%
print("Hello")
print()
print("Taro")

# %%
print("Hello",end=",")
print("Taro")

# %%
print("Hello","Taro")
print("Hello","Taro",sep=",")

# %%
print("Hello,Taro")

# %%
number=100
Number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 number=100
# ----> 2 Number
#
# NameError: name 'Number' is not defined

# %%
number=100
number
# Out:
# 100

# %%
name=input("what is your name?");print(name)
# Out:
# what is your name? Taro
# Taro

# %%
score=int(input("点数を入力"))
if score>=40:
    print("合格")
else:print("追試")
# Out:
# 点数を入力 12
# 追試

# %%
#name=input("what is your name?")
name="Taro"
print('Hello'+name)
# Out:
# HelloTaro

# %%
score=int(input("点数を入力"))
if score>=80:
    print("A")
    """
    elif score=40:
    print("C")
    """
else:
    print("追試")
# Out:
# 点数を入力 75
# 追試

# %%
data=[[1,2,3],
      [4,5,6],
      [7,8,9]]
print(data)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
number=1+2+3\
+4+5+6\
+7+8+9
print(number)
# Out:
# 45

# %%
number=1+2+3\
       +4+5+6\
       +7+8+9
print(number)
# Out:
# 45

# %%
age = input ("How old are you?")
print(age+"years old!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 age = input ("How old are you?")
#       2 print(age+"years old!")
#
# TypeError: 'list' object is not callable

# %% [markdown]
# # Assistant
# This error occurs when you try to use a variable name that has accidentally overwritten a built-in Python function. In this case, it seems like the `input` function has been overwritten somewhere in your code or notebook.
#
# The error message "TypeError 'list' object is not callable" suggests that `input` is now a list instead of a function, which happens when you assign a list to a variable named `input` earlier in your code.
#
# Would you like me to provide the corrected code?

# %%
age = input("How old are you?")
print(age + "years old!")
# Out:
# How old are you? 19
# 19years old!
